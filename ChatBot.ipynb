# %% [markdown]
# NLP Based Chatbot - Intent Classifier

# %%
#Tokenisation
from nltk.tokenize import word_tokenize
#Stopwords list 
from nltk.corpus import stopwords
#Stemming
from nltk.stem import PorterStemmer
#Lemmatization
from nltk.stem import WordNetLemmatizer
import string
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.linear_model import LogisticRegression

# %%
training_data=[
    ("hello","greet"),
    ("hi","greet"),
    ("hello there","greet"),
    ("hi there","greet"),
    ("hey","greet"),
    ("hey there","greet"),
    ("hi everyone","greet"),
    ("how are you","greet"),
    ("how are you doing","greet"),
    ("how are you doing today","greet"),
    ("good morning","greet"),
    ("good afternoon","greet"),
    ("good evening","greet"),
    ("good night","greet"),
    ("what's the weather like","weather"),
    ("what's the temperature","weather"),
    ("what's the climate","weather"),
    ("what's the humidity","weather"),
    ("what's the wind speed","weather"),
    ("what's the news today","news"),
    ("what are the headlines","news"),
    ("what's the trending news","news"),
    ("what's the latest news","news"),
    ("what's the latest headlines","news"),
    ("headlines","news"),
    ("news","news"),
    ("trending news","news"),
    ("what's trending in news","news"),
    ("where am i","location"),
    ("where are you","location"),
    ("where are we","location"),
    ("what's my location","location"),
    ("where","location"),
    ("where are you","location"),
    ("where are we","location"),
    ("what's my location","location"),
    ("what city am i in","location"),
    ("what country am i in","location"),
    ("what state am i in","location"),
    ("open google","open_web"),
    ("open youtube","open_web"),
    ("open facebook","open_web"),
    ("open instagram","open_web"),
    ("date","datetime"),
    ("time","datetime"),
    ("datetime","datetime"),
    ("date and time","datetime"),
    ("what's the date and time","datetime"),
    ("time and date","datetime"),
    ("what's the time and date","datetime"),
    ("What is the date today","datetime"),
    ("What is the time now","datetime"),
    ("what is current time","datetime"),
    ("bye","exit"),
    ("goodbye","exit"),
    ("see you later","exit"),
    ("see you soon","exit"),
    ("exit","exit")

]

# %%
sentences=[] # features / x
labels=[] # target / y
for text,intent in training_data:
    sentences.append(text)
    labels.append(intent)

# %%
def preprocess_text(documents):
    english_stopwords = stopwords.words("english")
    punctuations = string.punctuation
    cleaned_documents = []
    for doc in documents:
        # Step-1 : Lowercase
        raw_text = doc.lower()
        # print("After lowercase: ",raw_text)
        
        tokens = word_tokenize(raw_text)
        # print("Tokens:",tokens)

        filtered_tokens = []
        for word in tokens:
            if word not in english_stopwords:
                filtered_tokens.append(word)
        
        # print("Filtered Tokens :",filtered_tokens)

        clean_tokens = [word for word in filtered_tokens if word not in punctuations]
        # print("After removing punctuations:",clean_tokens)

        lemmatized_words = []
        wnet = WordNetLemmatizer()
        for word in clean_tokens:
            lemmatized_words.append(wnet.lemmatize(word,"v"))
        
        # print("After Lemmatization :",lemmatized_words)

        final_tokens = []
        for word in lemmatized_words:
            if word.isalpha():
                final_tokens.append(word)
        
        # print("Final Tokens:",final_tokens)

        cleaned_text = " ".join(final_tokens)
        # print("Cleaned Text:",cleaned_text)
        
        cleaned_documents.append(cleaned_text)
        # print("="*50)
    return cleaned_documents

# %%
sentences[:5]
# Out:
# ['hello', 'hi', 'hello there', 'hi there', 'hey']

# %%
cleaned_data = preprocess_text(sentences)

# %%
cleaned_data
# Out:
# ['hello',
#  'hi',
#  'hello',
#  'hi',
#  'hey',
#  'hey',
#  'hi everyone',
#  '',
#  '',
#  'today',
#  'good morning',
#  'good afternoon',
#  'good even',
#  'good night',
#  'weather like',
#  'temperature',
#  'climate',
#  'humidity',
#  'wind speed',
#  'news today',
#  'headline',
#  'trend news',
#  'latest news',
#  'latest headline',
#  'headline',
#  'news',
#  'trend news',
#  'trend news',
#  '',
#  '',
#  '',
#  'location',
#  '',
#  '',
#  '',
#  'location',
#  'city',
#  'country',
#  'state',
#  'open google',
#  'open youtube',
#  'open facebook',
#  'open instagram',
#  'date',
#  'time',
#  'datetime',
#  'date time',
#  'date time',
#  'time date',
#  'time date',
#  'date today',
#  'time',
#  'current time',
#  'bye',
#  'goodbye',
#  'see later',
#  'see soon',
#  'exit']

# %%
#applying tf-idf vectorization
vectorizer = TfidfVectorizer()
X = vectorizer.fit_transform(cleaned_data)
y = labels

#train model
model = LogisticRegression()
model.fit(X,y)
# Out:
# LogisticRegression()

# %%
user_msg = "hello how are you?"
processed= preprocess_text([user_msg])
user_vector = vectorizer.transform(processed)
prediction= model.predict(user_vector)
print("Prediction is: ",prediction)
# Out:
# Prediction is:  ['greet']

# %%
user_msg="open linkedin"
processed= preprocess_text([user_msg])
user_vector = vectorizer.transform(processed)
prediction= model.predict(user_vector)
print("Prediction is: ",prediction)
# Out:
# Prediction is:  ['open_web']

# %%
testdata=[
    "hello",
    "hi",
    "hello, how are you?",
    "hi there",
    "hey",
    "what's the weather like",
    "what's the temperature",
    "what's the climate",
    "what's the humidity",
    "what's the wind speed",
    "what's the news today",
    "what are the headlines",
    "what's trending in news",
    "where am i",
    "where are you",
    "where are we",
    "what's my location",
    "what city am i in",
    "what country am i in",
    "what state am i in",
    "open google",
    "open youtube",
    "open facebook",
    "open instagram",
    "date",
    "time",
    "datetime",
    "date and time",
    "what's the date and time",
    "time and date",
    "what's the time and date",
    "What is the date today",
    "What is the time now",
    "what is current time",
    "bye",
    "goodbye",
    "see you later",
    "see you soon",
    "exit"
]

# %%
processed_testdata = preprocess_text(testdata)
test_vectors = vectorizer.transform(processed_testdata)
predictions = model.predict(test_vectors)
for i,j in enumerate(predictions):
    print(f"User Message: {testdata[i]} --> Predicted Intent: {j}")
# Out:
# User Message: hello --> Predicted Intent: greet
# User Message: hi --> Predicted Intent: greet
# User Message: hello, how are you? --> Predicted Intent: greet
# User Message: hi there --> Predicted Intent: greet
# User Message: hey --> Predicted Intent: greet
# User Message: what's the weather like --> Predicted Intent: weather
# User Message: what's the temperature --> Predicted Intent: weather
# User Message: what's the climate --> Predicted Intent: weather
# User Message: what's the humidity --> Predicted Intent: weather
# User Message: what's the wind speed --> Predicted Intent: weather
# User Message: what's the news today --> Predicted Intent: news
# User Message: what are the headlines --> Predicted Intent: news
# User Message: what's trending in news --> Predicted Intent: news
# User Message: where am i --> Predicted Intent: location
# User Message: where are you --> Predicted Intent: location
# User Message: where are we --> Predicted Intent: location
# ...

# %%
#accuracy check
from sklearn.metrics import accuracy_score
accuracy=accuracy_score(testdata,predictions)
print(f"Accuracy is: {accuracy:.2f}")
# Out:
# Accuracy is: 0.05

# %%
import joblib
#Serialization - saving object 
#Deserialization - loading object

# %%
joblib.dump(model,"chatbot_model.pkl")
joblib.dump(vectorizer,"vectorizer.pkl")
# Out:
# ['vectorizer.pkl']
