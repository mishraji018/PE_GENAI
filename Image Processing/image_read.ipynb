# %%
pip install opencv-python
# Out:
# Requirement already satisfied: opencv-python in c:\Users\pmish\AppData\Local\Programs\Python\Python313\Lib\site-packages (4.13.0.92)
# Requirement already satisfied: numpy>=2 in c:\Users\pmish\AppData\Local\Programs\Python\Python313\Lib\site-packages (from opencv-python) (2.4.2)
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Ignoring invalid distribution ~ip (c:\Users\pmish\AppData\Local\Programs\Python\Python313\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~ip (c:\Users\pmish\AppData\Local\Programs\Python\Python313\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~ip (c:\Users\pmish\AppData\Local\Programs\Python\Python313\Lib\site-packages)

# %%
import cv2

# %%
img=cv2.imread('virat kohli.jpg')

# %%
type(img)
# Out:
# numpy.ndarray

# %%
img.shape
# Out:
# (300, 168, 3)

# %%
img[0]
# Out:
# array([[16, 10, 11],
#        [16, 10, 11],
#        [17, 11, 12],
#        [17, 11, 12],
#        [17, 11, 12],
#        [18, 12, 13],
#        [18, 12, 13],
#        [18, 12, 13],
#        [18, 12, 13],
#        [19, 13, 14],
#        [19, 13, 14],
#        [19, 13, 14],
#        [20, 14, 15],
#        [20, 14, 15],
#        [20, 14, 15],
#        [21, 15, 16],
#        [21, 15, 16],
#        [20, 14, 15],
#        [20, 14, 15],
#        [20, 14, 15],
#        [19, 13, 14],
#        [19, 13, 14],
#        [19, 13, 14],
#        [18, 12, 13],
#        [19, 13, 14],
#        [19, 13, 14],
#        [19, 13, 14],
#        [19, 13, 14],
#        [19, 13, 14],
#        [19, 13, 14],
#        [19, 13, 14],
#        [19, 13, 14],
#        [17, 11, 12],
#        [17, 11, 12],
#        [17, 11, 12],
#        [17, 11, 12],
#        [17, 11, 12],
#        [17, 11, 12],
#        [17, 11, 12],
#        [17, 11, 12],
#        [17, 11, 12],
#        [17, 11, 12],
#        [17, 11, 12],
#        [16, 10, 11],
#        [16, 10, 11],
#        [15,  9, 10],
#        [15,  9, 10],
#        [15,  9, 10],
#        [14,  8,  9],
#        [14,  8,  9],
#        [14,  8,  9],
#        [15,  9, 10],
#        [15,  9, 10],
#        [15,  9, 10],
#        [16, 10, 11],
#        [16, 10, 11],
#        [15,  9, 10],
#        [15,  9, 10],
#        [15,  9, 10],
#        [15,  9, 10],
#        [15,  9, 10],
#        [15,  9, 10],
#        [15,  9, 10],
#        [15,  9, 10],
#        [17, 11, 12],
#        [17, 11, 12],
#        [17, 11, 12],
#        [17, 11, 12],
#        [17, 11, 12],
#        [17, 11, 12],
#        [17, 11, 12],
#        [17, 11, 12],
#        [18, 12, 13],
#        [18, 12, 13],
#        [18, 12, 13],
#        [18, 12, 13],
#        [18, 12, 13],
#        [18, 12, 13],
#        [18, 12, 13],
#        [18, 12, 13],
#        [17, 11, 12],
#        [17, 11, 12],
#        [17, 11, 12],
#        [17, 11, 12],
#        [17, 11, 12],
#        [17, 11, 12],
#        [17, 11, 12],
#        [17, 11, 12],
#        [17, 11, 12],
#        [17, 11, 12],
#        [17, 11, 12],
#        [17, 11, 12],
#        [17, 11, 12],
#        [17, 11, 12],
#        [17, 11, 12],
#        [17, 11, 12],
#        [16, 10, 11],
#        [16, 10, 11],
#        [16, 10, 11],
#        [16, 10, 11],
#        [16, 10, 11],
#        [16, 10, 11],
#        [16, 10, 11],
#        [16, 10, 11],
#        [15,  9, 10],
#        [15,  9, 10],
#        [15,  9, 10],
#        [16, 10, 11],
#        [16, 10, 11],
#        [17, 11, 12],
#        [17, 11, 12],
#        [17, 11, 12],
#        [15,  9, 10],
#        [15,  9, 10],
#        [15,  9, 10],
#        [15,  9, 10],
#        [15,  9, 10],
#        [15,  9, 10],
#        [15,  9, 10],
#        [15,  9, 10],
#        [15,  9, 10],
#        [15,  9, 10],
#        [15,  9, 10],
#        [15,  9, 10],
#        [15,  9, 10],
#        [15,  9, 10],
#        [15,  9, 10],
#        [15,  9, 10],
#        [16, 10, 11],
#        [16, 10, 11],
#        [16, 10, 11],
#        [16, 10, 11],
#        [16, 10, 11],
#        [16, 10, 11],
#        [16, 10, 11],
#        [16, 10, 11],
#        [16, 10, 11],
#        [16, 10, 11],
#        [16, 10, 11],
#        [16, 10, 11],
#        [16, 10, 11],
#        [16, 10, 11],
#        [16, 10, 11],
#        [16, 10, 11],
#        [16, 10, 11],
#        [16, 10, 11],
#        [16, 10, 11],
#        [16, 10, 11],
#        [16, 10, 11],
#        [16, 10, 11],
#        [16, 10, 11],
#        [16, 10, 11],
#        [16, 10, 11],
#        [16, 10, 11],
#        [16, 10, 11],
#        [16, 10, 11],
#        [16, 10, 11],
#        [16, 10, 11],
#        [16, 10, 11],
#        [16, 10, 11],
#        [16, 10, 11],
#        [16, 10, 11],
#        [16, 10, 11],
#        [16, 10, 11],
#        [16, 10, 11],
#        [16, 10, 11],
#        [16, 10, 11],
#        [16, 10, 11]], dtype=uint8)

# %%
import matplotlib.pyplot as plt
img=cv2.cvtColor(img,cv2.COLOR_BGR2RGB)
plt.imshow(img)

# %%
#Show image window
cv2.imshow('virat kohli',img)

#Loop to check key press
while True:
    key=cv2.waitKey(0) & 0xFF
    #ESC 27 is more reliable than 'q'
    if key==27:
        break

cv2.destroyAllWindows()
