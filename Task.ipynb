# %%
import string
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer

sentences=[
"I am Learning python",
"We are happy today",
"I am sad today"
]

def preprocess_text(documents):
    english_stopwords = stopwords.words('english')
    punctuations= string.punctuation
    cleaned_documents=[]
    for doc in documents:
        #Step-1: Lowercase
        raw_text=doc.lower()
        print("Lowercase: ",raw_text)

        tokens=word_tokenize(raw_text)
        print("Tokens: ",tokens)

        filtered_tokens=[word for word in tokens if word not in english_stopwords]
        print("After Removing Stopwords: ",filtered_tokens)

        #Step-2: Removing Punctuation
        punctuations = '''!()-[]{};:'"\,<>./?@#$%^&*_~'''
        clean_tokens=[word for word in tokens if word not in punctuations]
        print("After Removing Punctuation: ",clean_tokens)

        #Step-3: Removing stopwords
        english_stopwords = stopwords.words('english')
        filtered_tokens=[word for word in clean_tokens if word not in english_stopwords]
        print("After Removing Stopwords: ",filtered_tokens)
        #Step-4: Stemming
cleaned_sentences=preprocess_text(sentences)
print(cleaned_sentences)
#Expected Output: ['learn python', 'happy today', 'sad today']
# Out:
# <>:28: SyntaxWarning: invalid escape sequence '\,'
# <>:28: SyntaxWarning: invalid escape sequence '\,'
# C:\Users\pmish\AppData\Local\Temp\ipykernel_29196\1511845009.py:28: SyntaxWarning: invalid escape sequence '\,'
#   punctuations = '''!()-[]{};:'"\,<>./?@#$%^&*_~'''
# Lowercase:  i am learning python
# Tokens:  ['i', 'am', 'learning', 'python']
# After Removing Stopwords:  ['learning', 'python']
# After Removing Punctuation:  ['i', 'am', 'learning', 'python']
# After Removing Stopwords:  ['learning', 'python']
# Lowercase:  we are happy today
# Tokens:  ['we', 'are', 'happy', 'today']
# After Removing Stopwords:  ['happy', 'today']
# After Removing Punctuation:  ['we', 'are', 'happy', 'today']
# After Removing Stopwords:  ['happy', 'today']
# Lowercase:  i am sad today
# Tokens:  ['i', 'am', 'sad', 'today']
# After Removing Stopwords:  ['sad', 'today']
# After Removing Punctuation:  ['i', 'am', 'sad', 'today']
# After Removing Stopwords:  ['sad', 'today']
# None
