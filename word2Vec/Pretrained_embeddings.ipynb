# %%
#use Pretrained Embeddings
#2 popular pretrained models:
#1.google news Word2vec(300)
#2.GloVe(Stanford)

# %%
import gensim.downloader as api

print("Loading pretrained models: ")
model=api.load("word2vec-google-news-300")
# Out:
# Loading pretrained models:
# [==================================================] 100.0% 1662.8/1662.8MB downloaded

# %%
model1=api.load("glove-wiki-gigaword-100")
# Out:
# [==================================================] 100.0% 128.1/128.1MB downloaded

# %%
print(model.most_similar("Happy",topn=15))
# Out:
# [('Tail_Ale', 0.601550817489624), ('Actor_Jeremy_Northam', 0.577749490737915), ('Merry_Christmas_Happy', 0.5536129474639893), ('Happy_Belated', 0.5421518683433533), ('Happy_belated', 0.5317155122756958), ('Gung_Hay_Fat_Choy', 0.5269104838371277), ('Blog_Hoggers', 0.5261031985282898), ('Happy_Valentines_Day', 0.5243179798126221), ('Belated_Birthday', 0.5228846669197083), ('Valentine_Daze', 0.5215494632720947), ('Lucky', 0.5197088718414307), ('Happy_Anniversary', 0.518598735332489), ('Happier', 0.517204999923706), ('Happy_Valentine_Day', 0.5166665315628052), ('Contented', 0.515102744102478)]
